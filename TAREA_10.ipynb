# %% [markdown]
# <a href="https://colab.research.google.com/github/luisangel22091102/TAREAS-DE-METODOS-DE-SIMULACION/blob/main/TAREA_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **MENDEZ VASQUEZ LUIS ANGEL**

# %%
import numpy as np
import matplotlib.pyplot as plt


def monte_carlo_integration(f, a, b, N):
    x = np.random.uniform(a, b, N)
    integral = (b - a) * np.mean(f(x))
    return integral


f = lambda x: x**2


a, b = 0, 1
N = 10000


result = monte_carlo_integration(f, a, b, N)
print(f"Monte Carlo Integration result: {result}")


x = np.linspace(0, 5, 500)
y1 = x**4 * np.exp(-2 * x)
y2 = (x**2 * np.exp(-x) * np.sin(x**2))**2

plt.figure(figsize=(10, 6))
plt.plot(x, y1, label=r'$x^4 e^{-2x}$')
plt.plot(x, y2, label=r'$(x^2 e^{-x} \sin(x^2))^2$')
plt.title("Graphs of Functions")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()


time = np.linspace(0, 10, 100)
counts = 100 * np.exp(-0.3 * time) + np.random.normal(0, 5, len(time))

plt.figure(figsize=(10, 6))
plt.plot(time, counts, 'bo', label="Experimental Data")
plt.title("Counts vs Time")
plt.xlabel("Time (s)")
plt.ylabel("Counts")
plt.legend()
plt.grid(True)
plt.show()


ln_counts = np.log(counts)


plt.figure(figsize=(10, 6))
plt.plot(time, ln_counts, 'ro', label="ln(Counts)")
plt.title("Logarithmic Transformation of Data")
plt.xlabel("Time (s)")
plt.ylabel("ln(Counts)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Monte Carlo Integration result: 0.32881151680369897
# <ipython-input-2-4c0efd636a85>:51: RuntimeWarning: invalid value encountered in log
#   ln_counts = np.log(counts)
